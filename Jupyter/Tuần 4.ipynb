# %%
#W4A1
n=int(input())
summ=0
for i in range (1,n+1):
    summ+=i
print(summ)
# Out:
# 6

# %%
#W4A2
n=int(input())
kt=False
while kt==False:
    if n<=0:
        n=int(input())
    else:
        kt=True
checksnt=True
for i in range (2,int(n**(0.5))+1):
    if n%i==0:
        checksnt=False
        break
print(checksnt)
# Out:
# True

# %%
#W4A3
n=int(input())
kq=1
for i in range (1,n+1):
    kq=kq*i
print(kq)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
#W4A4
n=abs(int(input()))
count=0
while n>0:
    n=n//10
    count+=1
print(count)
# Out:
# 4

# %%
#W4A5
n=int(input())
lst=[int(i) for i in input().split()]
if 42 in lst:
    print("I've found the meaning of life" )
else:
    print("It's a joke")
# Out:
# I've found the meaning of life

# %%
#W4A6
a,b=map(int,input().split())
def sangnt(a,n):
    sang=[1]*(n+1)
    sang[0]=sang[1]=0
    for i in range (2,int(n*0.5)+1):
        if sang[i]==1:
            for j in range (i*i,n+1,i):
                sang[j]=0
    tong=0
    for i in range (a,n+1):
        if sang[i]==1:
            tong+=i
    return tong
result=sangnt(a,b)
print(result)
# Out:
# 60

# %%
#W4A7
def sangnt(n):
    prime_lst=[1]*(n+1)
    prime_lst[0]=prime_lst[1]=0
    tr_prime_lst=[]
    for i in range (2,int(n**(0.5))+1):
        if prime_lst[i]==1:
            tr_prime_lst.append(i)
            for j in range (i*i,int(n*(0.5))+1,i):
                prime_lst[j]=0
    return tr_prime_lst
n=int(input())
prime_lst=sangnt(n)
for i in prime_lst:
    while n%i==0:
        n=n/i
    if n==1:
        result=i
        break
if n!=1:
    result=n
print(int(result))
# Out:
# 2

# %%
#W4A8
def check_palindrome(st):
    if st==st[::-1]:
        return True
    else:
        return False
n=input()
count=0
while check_palindrome(n) == False:
    n=str(int(n[::-1])+int(n))
    count+=1

print(count,n)
# Out:
# 4 4884

# %%
#W4A9
def pairwise_distinct(n):
    check=[0]*10
    for i in str(n):
        if check[int(i)]==1:
            return False
        else:
            check[int(i)]+=1
    return True


n=50
result=[]
for i in range (1,int(n**(0.5))+1):
    if pairwise_distinct(i**2):
        result.append(i**2)
if len(result)==0:
    print("no number")
else:
    print(*result)
# Out:
# 1 4 9 16 25 36 49

# %%
#W4A10
n=10
def collatz(n):
    count=1
    while n!=1:
        if n%2==0:
            n=n//2
        else:
            n=n*3+1
        count+=1
    return count
long=[0,float("-inf")]
for i in range (1,n+1):
    a,b=i,collatz(i)
    if b>long[1]:
        long[0],long[1]=a,b
print(long)
# Out:
# [9, 20]

# %%
#W4A11
n=int(input())
count=0
if n%2==0:
    for i in range (1,int(n**(0.5))+1):
        if n%i==0:
            if i%2==0:
                count+=1
                if (n/i)%2==0:
                    count+=1
            else:
                if (n/i)%2==0:
                    count+=1
print(count)
# Out:
# 43

# %%
#W4A12
x=1000
n=12
result=x*(1+0.7/100)**n
print(f"{result:.0f}")
# Out:
# 1087

# %%
#W4A13
a,b=map(int, input().split())
divisor=1
for i in range (2,int(a**(0.5))+1):
    if a%i==0:
        divisor=divisor+i+a//i
if divisor==b:
    print(True)
else:
    print(False)
# Out:
# True

# %%
#W4A14
def ucln(a,b):
    while b!=0:
        a,b=b,a%b
    return a
a,b=map(int, input().split())
ucln(a,b)
# Out:
# 1

# %%
#15
a,b=map(int,input().split())
if (b-a*2)%2==0:
    cho=(b-a*2)//2
    ga=a-cho
    print(ga,cho)
else:
    print("invalid")
# Out:
# 22 14

# %%
#16
for i in range (6,100,6):
    print(i,end= " ")
# Out:
# 6 12 18 24 30 36 42 48 54 60 66 72 78 84 90 96

# %%
#17
a=5
for i in range (1,11):
    print(f"{a}x{i}={a*i}")
# Out:
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45
# 5x10=50

# %%
#18
a,b=map(int,input().split())
k=ucln(a,b)
for i in range (1,k+1):
    if k%i==0:
        print(i)
# Out:
# 1
# 2
# 4
# 8

# %%
#19
n=int(input())
for i in range (2,n+1,2):
    print(i,end=' ')
# Out:
# 2 4 6

# %%
#20
n=int(input())
while n%2==0:
    n=n/2
if n==1:
    print(True)
else:
    print(False)
# Out:
# True

# %%
#21
n=int(input())
rs=0
while n!=0:
    x=n%10
    n=n//10
    rs+=x
print(rs)
# Out:
# 10

# %%
#22
n=input()
def kt(n):
    if n%2==0:
        return True
    else:
        return False
chan=0
le=0
for i in n:
    if kt(int(i))==True:
        chan+=1
    else:
        le+=1
print(chan, le)
# Out:
# 4 4

# %%
#23
n=int(input())
tong=0
k=1
while tong<=n:
    tong+=k
    k+=1
print(k-2)
# Out:
# 3

# %%
#24
a=int(input())
n=1
tong=0
while tong<=a:
    tong+=1/n
    n+=1
print(n-2)
# Out:
# 3

# %%
#25
x=int(input())
maxx_num=float("-inf")
minn_num=float("inf")
if minn_num>x:
    minn_num=x
if maxx_num<x:
    maxx_num=x
while x!=-1:
    x=int(input())
    if minn_num>x:
        minn_num=x
    if maxx_num<x:
        maxx_num=x
print(maxx_num,minn_num)
# Out:
# 8 -3

# %%
#26
a=int(input())
if a==1:
    print(1)
if a==0:
    print(0)
if not(a==0 or a==1):
    fib=[0,1]
    while fib[-1]<=a:
        fib.append(fib[-1]+fib[-2])
    print(fib[-2])
# Out:
# 5

# %%
#27
string=input()
count=0
kt=0
for i in string:
    if i==' ':
        kt=0
    elif kt==0:
        count+=1
        kt=1
print(count)
# Out:
# 5

# %%
#28
string=input()
kt=0
kq=''
for i in string:
    if i==' ' and kt==1:
        break
    if i==' ':
        kt=0
    elif kt==0:
        kq+=i
        kt=1
    else:
        kq+=i
print(kq)
# Out:
# acb

# %%
#29
nums=input()
kt=0
num=''
tong=0
for i in nums:
    if i.isdigit()==False:
        kt=0
    else:
        kt=1   
    if kt==1:
        num+=i
    elif num!='':
        tong+=int(num)
        num=''
if kt==1:
    tong+=int(num)
print(tong)
# Out:
# 3
# 12
# 30

# %%
#30
string=input()
hoa=0
thuong=0
so=0
for i in string:
    if 'a'<=i<='z':
        thuong+=1
    if 'A'<=i<='Z':
        hoa+=1
    if '0'<=i<='9':
        so+=1
print(hoa, thuong, so)
# Out:
# 3 3 3

# %%
#31
string=input()
tong=0
for i in string:
    if '0'<=i<='9':
        tong+=int(i)
print(tong)
# Out:
# 24

# %%
#32
string=input()
length=0
spec=0
up=0
num=0
norm=0
for i in string:
    length+=1
    if '0'<=i<='9':
        num+=1
    elif 'a'<=i<='z':
        norm+=1
    elif 'A'<=i<='Z':
        up+=1
    elif i!=' ':
        spec+=1
if length>6 and spec>=1 and up>=1 and num>=1 and norm >=1:
    print(True)
else:
    print(False)
# Out:
# True
# 1

# %%
#33
num=int(input())
num=str(num)
new=''
for i in range (0,len(num),3):
    new=new+num[i:i+3]+'.'
if new[-1]=='.':
    new=new[:-1]
print(new)
# Out:
# 375.469.485

# %%
#34
a=input()
b=input()
b_length=len(b)
while True:
    location=a.find(b)
    if location==-1:
        break
    a=a[:location]+a[location+b_length:]
print(a)
# Out:
# bcbc
